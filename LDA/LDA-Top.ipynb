# %% [markdown]
# ## Import required library

# %%
import nltk
nltk.download('punkt')
import pandas as pd
import spacy
import nltk
import string
from nltk.corpus import stopwords
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Data preprocessing

# %%
import pandas as pd
top_df = pd.read_csv('Top_Artists.csv')
top_df.head()
# Out:
#                        SongName                                 AlbumName  \
# 0            BIRDS OF A FEATHER                      HIT ME HARD AND SOFT
# 1  you should see me in a crown  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 2                      GOLDWING                         Happier Than Ever
# 3                 Getting Older                         Happier Than Ever
# 4                    Your Power                         Happier Than Ever
#
#                                            AlbumLink  Year   PlayCount  \
# 0  https://open.spotify.com/album/7aJuG4TFXa2hmE4...  2024  3218891371
# 1  https://open.spotify.com/album/0S0KGZnfBGSIssf...  2019  1000101010
# 2  https://open.spotify.com/album/0JGOiO34nwfUdDr...  2021   162632187
# 3  https://open.spotify.com/album/0JGOiO34nwfUdDr...  2021   334347982
# 4  https://open.spotify.com/album/0JGOiO34nwfUdDr...  2021   526977340
#
#                                               Lyrics  \
# 0  ('Til I'm in the grave)\r\nI want you to stay\...
# 1  Bite my tongue, bide my time\r\nWearing a warn...
# 2  He hath come to the bosom of his beloved\r\nSm...
# 3  I'm getting older, I think I'm aging well\r\nI...
# 4  Try not to abuse your power\r\nI know we didn'...
#
#                                             SongLink  Duration        artist
# 0  https://open.spotify.com/track/6dOtVTDdiauQNBQ...       210  Billie_Ilish
# 1  https://open.spotify.com/track/3XF5xLJHOQQRbWy...       180  Billie_Ilish
# 2  https://open.spotify.com/track/0FfqyjhB6Kspvit...       151  Billie_Ilish
# 3  https://open.spotify.com/track/4HOryCnbme0zBnF...       244  Billie_Ilish
# 4  https://open.spotify.com/track/042Sl6Mn83JHyLE...       245  Billie_Ilish

# %%
# Load the English model from spaCy
nlp = spacy.load("en_core_web_sm")

# Create a set of English stopwords
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    doc = nlp(text.lower())
    tokens = [
        token.lemma_ for token in doc
        if token.is_alpha and token.text not in stop_words
    ]
    return " ".join(tokens)

# %%
Top_lyrics['Lyrics'] = top_df['Lyrics'].apply(preprocess_text)
Top_lyrics.head()
# Out:
#                                               Lyrics weird_chars  \
# 0  til grave want stay til grave til rot away dea...          []
# 1  bite tongue bide time wear warning sign wait t...          []
# 2  hath come bosom beloved smile beareth high yea...          []
# 3  get old think age well wish someone tell reaso...          []
# 4  try abuse power know choose change might wanna...          []
#
#                                         clean_lyrics
# 0  til grave want stay til grave til rot away dea...
# 1  bite tongue bide time wear warning sign wait t...
# 2  hath come bosom beloved smile beareth high yea...
# 3  get old think age well wish someone tell reaso...
# 4  try abuse power know choose change might wanna...

# %%
Top_lyrics = pd.DataFrame(Top_lyrics['Lyrics'])
Top_lyrics.head()
# Out:
#                                               Lyrics
# 0  til grave want stay til grave til rot away dea...
# 1  bite tongue bide time wear warning sign wait t...
# 2  hath come bosom beloved smile beareth high yea...
# 3  get old think age well wish someone tell reaso...
# 4  try abuse power know choose change might wanna...

# %%
lyric_fillers = [
    "oh", "ooh", "ooo", "ah", "aah", "mm", "mmm", "mmh",
    "eh", "hey", "ha", "la", "da", "nah", "yeah", "yea","bitch", "shit", "fuck", "nigga", "na", "niggas", "whoa",
    "woah", "ya" , "hol", "whoo", "gon",
    "pop" , "know" , "say" , "man",
    "di", "huh", "uh" , "woo" ,"yah"
]

# %%
def clean_text_lda(text):
    text = text.lower()
    text = re.sub(r"[^\x00-\x7F]", " ", text)  # Remove ASCII outside
    text = re.sub(r"[^a-z\s]", " ", text)     # a–z
    text = re.sub(r"\s+", " ", text)          # Multiple spaces to single space
    pattern = r"\b(" + "|".join(lyric_fillers) + r")\b" # remove fillers
    text = re.sub(pattern, " ", text)
    return text.strip()

Top_lyrics["clean_lyrics"] = Top_lyrics["Lyrics"].apply(clean_text_lda)

# %% [markdown]
# ### Double check

# %%
from collections import Counter

all_weird = []
for t in Top_lyrics["clean_lyrics"]:
    all_weird.extend(re.findall(r"[^a-zA-Z0-9\s]", t))

Counter(all_weird).most_common(20)
# Out:
# []

# %% [markdown]
# ### LDA

# %%
Top_lyrics.head()
# Out:
#                                               Lyrics  \
# 0  til grave want stay til grave til rot away dea...
# 1  bite tongue bide time wear warning sign wait t...
# 2  hath come bosom beloved smile beareth high yea...
# 3  get old think age well wish someone tell reaso...
# 4  try abuse power know choose change might wanna...
#
#                                         clean_lyrics  Top_LDA_Topic  \
# 0  til grave want stay til grave til rot away dea...              3
# 1  bite tongue bide time wear warning sign wait t...              3
# 2  hath come bosom beloved smile beareth high yea...              1
# 3  get old think age well wish someone tell reaso...              3
# 4  try abuse power   choose change might wanna lo...              3
#
#                                   LDA_Topic_Keywords
# 0  love, like, baby, time, feel, make, come, tell...
# 1  love, like, baby, time, feel, make, come, tell...
# 2  like, make, need, look, come, want, money, god...
# 3  love, like, baby, time, feel, make, come, tell...
# 4  love, like, baby, time, feel, make, come, tell...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Text to vector
vectorizer = CountVectorizer(stop_words="english")
doc_term_matrix = vectorizer.fit_transform(Top_lyrics["clean_lyrics"])
feature_names = vectorizer.get_feature_names_out()

# %% [markdown]
# #### Decide the number of topics

# %%
# LDA Model and Perplexity Calculation
for n_topics in range(2, 15):
    model = LatentDirichletAllocation(n_components=n_topics, random_state=0)
    model.fit(doc_term_matrix)
    perplexity = model.perplexity(doc_term_matrix)
    print(f"Topics: {n_topics} → Perplexity: {perplexity:.2f}")
# Out:
# Topics: 2 → Perplexity: 1903.09
# Topics: 3 → Perplexity: 1867.14
# Topics: 4 → Perplexity: 1864.38
# Topics: 5 → Perplexity: 1896.60
# Topics: 6 → Perplexity: 1907.01
# Topics: 7 → Perplexity: 1909.30
# Topics: 8 → Perplexity: 1881.95
# Topics: 9 → Perplexity: 1889.80
# Topics: 10 → Perplexity: 1884.62
# Topics: 11 → Perplexity: 1881.84
# Topics: 12 → Perplexity: 1879.13
# Topics: 13 → Perplexity: 1884.31
# Topics: 14 → Perplexity: 1889.27

# %%
import matplotlib.pyplot as plt

perplexities = []
topic_range = range(2, 15)

for n_topics in topic_range:
    model = LatentDirichletAllocation(n_components=n_topics, random_state=0)
    model.fit(doc_term_matrix)
    perplexity = model.perplexity(doc_term_matrix)
    perplexities.append(perplexity)

plt.figure(figsize=(8, 5))
plt.plot(topic_range, perplexities, marker='o')
plt.title("LDA Model Perplexity vs. Number of Topics")
plt.xlabel("Number of Topics")
plt.ylabel("Perplexity")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Elbow + minium region ==> N=4

# %%
n_topics = 4  # Can be adjusted based on analysis
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_model.fit(doc_term_matrix)

# Get the top keywords (top 7) for each topic
topic_words = []
for topic_idx, topic in enumerate(lda_model.components_):
    top_features = [feature_names[i] for i in topic.argsort()[:-15:-1]]
    topic_words.append(", ".join(top_features))

# Assign the most probable topic and its representative keywords to each question
doc_topic_distrib = lda_model.transform(doc_term_matrix)  # ✅ Using doc_term_matrix here as well
Top_lyrics["Top_LDA_Topic"] = doc_topic_distrib.argmax(axis=1)
Top_lyrics["LDA_Topic_Keywords"] = Top_lyrics["Top_LDA_Topic"].apply(lambda x: topic_words[x])

Top_lyrics.head()
# Out:
#                                               Lyrics  \
# 0  til grave want stay til grave til rot away dea...
# 1  bite tongue bide time wear warning sign wait t...
# 2  hath come bosom beloved smile beareth high yea...
# 3  get old think age well wish someone tell reaso...
# 4  try abuse power know choose change might wanna...
#
#                                         clean_lyrics  Top_LDA_Topic  \
# 0  til grave want stay til grave til rot away dea...              0
# 1  bite tongue bide time wear warning sign wait t...              0
# 2  hath come bosom beloved smile beareth high yea...              3
# 3  get old think age well wish someone tell reaso...              0
# 4  try abuse power   choose change might wanna lo...              0
#
#                                   LDA_Topic_Keywords
# 0  like, baby, let, time, make, feel, love, tell,...
# 1  like, baby, let, time, make, feel, love, tell,...
# 2  love, come, like, girl, baby, long, need, look...
# 3  like, baby, let, time, make, feel, love, tell,...
# 4  like, baby, let, time, make, feel, love, tell,...

# %%
Top_lyrics["LDA_Topic_Keywords"].value_counts()
# Out:
# LDA_Topic_Keywords
# like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come      628
# like, come, high, want, make, night, life, money, need, real, really, let, tell, big    193
# like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new     189
# love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way        140
# Name: count, dtype: int64

# %% [markdown]
# ### Transformer to generate topic

# %%
import torch
import torch.nn.functional as F
from transformers import (
    AutoTokenizer, AutoModelForSequenceClassification,
    GPT2LMHeadModel, GPT2Tokenizer,
    pipeline
)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# YOUR CODE HERE:
# 1. Load GPT-2 model and tokenizer
print("Loading GPT-2 tokenizer...")
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

model = GPT2LMHeadModel.from_pretrained('gpt2')
model = model.to(device)
model.eval()  # Set to evaluation mode

# 2. Create function to generate product descriptions
#    def generate_description(prompt, **generation_params):
#        # Your implementation
#        pass
def generate_text(prompt,
                  max_length=50,
                  temperature=1.0,
                  top_k=50,
                  top_p=0.95,
                  num_return_sequences=1):
    """
    Generate text using GPT-2.

    Args:
        prompt: Starting text
        max_length: Maximum length of generated text
        temperature: Randomness (higher = more random)
        top_k: Consider top k words
        top_p: Nucleus sampling threshold
        num_return_sequences: Number of generations to return

    Returns:
        List of generated texts
    """
    # Encode the prompt
    input_ids = tokenizer.encode(prompt, return_tensors='pt').to(device)

    # Generate
    with torch.no_grad():
        output = model.generate(
            input_ids,
            max_length=max_length,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p,
            num_return_sequences=num_return_sequences,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    # Decode and return
    generated_texts = []
    for i in range(num_return_sequences):
        text = tokenizer.decode(output[i], skip_special_tokens=True)
        generated_texts.append(text)

    return generated_texts

print("✓ Generation function ready!")

# 3. Generate descriptions for 3 product categories
#    Try different parameters:
#    - temperature (0.7, 1.0)
#    - top_k (50, 100)
#    - top_p (0.9, 0.95)
#    - max_length (50, 100)

product_prompts = {
    "Topic1": "Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come.",
    "Topic2": "Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big.",
    "Topic3": "Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new.",
    "Topic4": "Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way."
}

# Different generation configurations
generation_configs = [
    {"name": "temp_0.7_topk_50", "temperature": 0.7, "top_k": 50, "top_p": 0.9,  "max_length": 50},
    {"name": "temp_1.0_topk_50", "temperature": 1.0, "top_k": 50, "top_p": 0.95, "max_length": 50},
    {"name": "temp_0.7_topk_100","temperature": 0.7, "top_k": 100,"top_p": 0.9,  "max_length": 100},
    {"name": "temp_1.0_topk_100","temperature": 1.0, "top_k": 100,"top_p": 0.95, "max_length": 100},
]

generated_results = []

for category, prompt in product_prompts.items():
    print(f"\n=== Category: {category} ===")
    print(f"Prompt: {prompt}\n")

    for cfg in generation_configs:
        text = generate_text(
            prompt,
            max_length=cfg["max_length"],
            temperature=cfg["temperature"],
            top_k=cfg["top_k"],
            top_p=cfg["top_p"],
            num_return_sequences=1
        )[0]

        print(f"[{cfg['name']}]")
        print(text)
        print("-" * 60)

        generated_results.append({
            "category": category,
            "config": cfg["name"],
            "text": text
        })

# 4. Implement quality checks:
#    - Length check
#    - Inappropriate content filter
#    - Relevance check
bad_words = []
def quality_check(text, category, min_words=20):
    """
    Return a dictionary containing:
    -length_ok: whether the text is long enough
    -has_bad_content: whether the text includes inappropriate words
    -relevant: whether the text is related to the category (checked using simple keywords)
    """
    lower = text.lower()
    words = lower.split()

    # lenth check
    length_ok = len(words) >= min_words

    # unappropriate content check
    has_bad = any(bad in lower for bad in bad_words)

    # relevance check
    keywords_map = {
        "Electronics": ["headphone", "headphones", "wireless", "audio"],
        "Home & Kitchen": ["coffee", "kitchen", "maker", "brew"],
        "Clothing": ["jacket", "coat", "winter", "warm"]
    }
    keywords = keywords_map.get(category, [])
    relevant = any(kw in lower for kw in keywords)

    return {
        "length_ok": length_ok,
        "has_bad_content": has_bad,
        "relevant": relevant
    }

print("\n=== Quality checks ===")
for item in generated_results:
    qc = quality_check(item["text"], item["category"])
    print(f"\nCategory: {item['category']} | Config: {item['config']}")
    print(f"Length OK:         {qc['length_ok']}")
    print(f"Inappropriate?:    {qc['has_bad_content']}")
    print(f"Relevant to topic: {qc['relevant']}")
# Out:
# Loading GPT-2 tokenizer...
# ✓ Generation function ready!
#
# === Category: Topic1 ===
# Prompt: Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come.
#
# [temp_0.7_topk_50]
# Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come.
#
# And so, I think the answer is, yes
# ------------------------------------------------------------
# [temp_1.0_topk_50]
# Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come.
#
# This is a way of thinking I find inspiring.
# ------------------------------------------------------------
# [temp_0.7_topk_100]
# Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come. Let's say you're not gonna let me. I'll say, if you want me, you can take me.
#
# Then you can say something like, "I'm going to let you take me." And that's how it works.
#
# But that's not how it works. It's
# ------------------------------------------------------------
# [temp_1.0_topk_100]
# Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come. and add your own. Like, let's say I wanna get married but I have a really nice first date and am still shy about it. I wish that I were born with a strong desire, but the fact that my mind, and body, is all too willing to see any kind of romantic or non
# ------------------------------------------------------------
#
# === Category: Topic2 ===
# Prompt: Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big.
#
# [temp_0.7_topk_50]
# Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big.
#
# I can't do that.
#
# I'm
# ------------------------------------------------------------
# [temp_1.0_topk_50]
# Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big. "You're so good here" is something you can hear
# ------------------------------------------------------------
# [temp_0.7_topk_100]
# Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big. In the end, if you're feeling good, you'll love this.
#
# I've seen some of these, and I've seen others, but I'm not going to get into them.
#
# If you're looking for a way to get more of these words in your lyrics, go for it
# ------------------------------------------------------------
# [temp_1.0_topk_100]
# Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big. All your choices would be in 1 gram, so if you like them the way you feel most, try it! When a song comes out with no lyrics you're going to write for it, because there are many more words you could call out to every listener and say, "what a perfect piece!" or
# ------------------------------------------------------------
#
# === Category: Topic3 ===
# Prompt: Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new.
#
# [temp_0.7_topk_50]
# Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new.
#
# If you think that's too easy, check out
# ------------------------------------------------------------
# [temp_1.0_topk_50]
# Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new. All are beautiful songs, like.
#
# Now we know
# ------------------------------------------------------------
# [temp_0.7_topk_100]
# Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new. And add a few more words like, love, happiness, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love,
# ------------------------------------------------------------
# [temp_1.0_topk_100]
# Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new. (When he hears this, don't bother paying for it.) There are a variety of ways to process it, including
#
# Using
#
# When you want to get to know something that you've never heard before
#
# Using
#
# To learn something new. The most obvious method, I think, is
# ------------------------------------------------------------
#
# === Category: Topic4 ===
# Prompt: Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way.
#
# [temp_0.7_topk_50]
# Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. This is a list of songs that are from the same genre
# ------------------------------------------------------------
# [temp_1.0_topk_50]
# Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. And all those things that are good for you.
#
#
# ------------------------------------------------------------
# [temp_0.7_topk_100]
# Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. It's a real job to make it.
#
# I do this because I want to make it. I want to make it because I want to make it. I want to make it because I want to make it.
#
# I want to make it because I want to make it.
#
# I
# ------------------------------------------------------------
# [temp_1.0_topk_100]
# Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. Remember: these words are all about music, and if you don't know anything about music, you probably don't want to write a song. Be creative and find a song based on these words, and then decide where to draw the line between love, come, like, girl, baby, long, need
# ------------------------------------------------------------
#
# === Quality checks ===
#
# Category: Topic1 | Config: temp_0.7_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic1 | Config: temp_1.0_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic1 | Config: temp_0.7_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic1 | Config: temp_1.0_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic2 | Config: temp_0.7_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic2 | Config: temp_1.0_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic2 | Config: temp_0.7_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic2 | Config: temp_1.0_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic3 | Config: temp_0.7_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic3 | Config: temp_1.0_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic3 | Config: temp_0.7_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic3 | Config: temp_1.0_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic4 | Config: temp_0.7_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic4 | Config: temp_1.0_topk_50
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic4 | Config: temp_0.7_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False
#
# Category: Topic4 | Config: temp_1.0_topk_100
# Length OK:         True
# Inappropriate?:    False
# Relevant to topic: False

# %%
top_topics = pd.DataFrame(generated_results)
pd.set_option('display.max_colwidth', None)  # 不限制文字長度 
top_topics
# Out:
#    category             config  \
# 0    Topic1   temp_0.7_topk_50
# 1    Topic1   temp_1.0_topk_50
# 2    Topic1  temp_0.7_topk_100
# 3    Topic1  temp_1.0_topk_100
# 4    Topic2   temp_0.7_topk_50
# 5    Topic2   temp_1.0_topk_50
# 6    Topic2  temp_0.7_topk_100
# 7    Topic2  temp_1.0_topk_100
# 8    Topic3   temp_0.7_topk_50
# 9    Topic3   temp_1.0_topk_50
# 10   Topic3  temp_0.7_topk_100
# 11   Topic3  temp_1.0_topk_100
# 12   Topic4   temp_0.7_topk_50
# 13   Topic4   temp_1.0_topk_50
# 14   Topic4  temp_0.7_topk_100
# 15   Topic4  temp_1.0_topk_100
#
#                                                                                                                                                                                                                                                                                                                                                                                                        text
# 0                                                                                                                                                                                                                                     Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come.\n\nAnd so, I think the answer is, yes
# 1                                                                                                                                                                                                                            Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come.\n\nThis is a way of thinking I find inspiring.
# 2                                                           Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come. Let's say you're not gonna let me. I'll say, if you want me, you can take me.\n\nThen you can say something like, "I'm going to let you take me." And that's how it works.\n\nBut that's not how it works. It's
# 3             Write a topic of song based on these words: like, baby, let, time, make, feel, love, tell, wanna, want, need, right, way, come. and add your own. Like, let's say I wanna get married but I have a really nice first date and am still shy about it. I wish that I were born with a strong desire, but the fact that my mind, and body, is all too willing to see any kind of romantic or non
# 4                                                                                                                                                                                                                                              Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big.\n\nI can't do that.\n\nI'm
# 5                                                                                                                                                                                                                         Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big. "You're so good here" is something you can hear
# 6                                         Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big. In the end, if you're feeling good, you'll love this.\n\nI've seen some of these, and I've seen others, but I'm not going to get into them.\n\nIf you're looking for a way to get more of these words in your lyrics, go for it
# 7   Write a topic of song based on these words: like, come, high, want, make, night, life, money, need, real, really, let, tell, big. All your choices would be in 1 gram, so if you like them the way you feel most, try it! When a song comes out with no lyrics you're going to write for it, because there are many more words you could call out to every listener and say, "what a perfect piece!" or
# 8                                                                                                                                                                                                                               Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new.\n\nIf you think that's too easy, check out
# 9                                                                                                                                                                                                                            Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new. All are beautiful songs, like.\n\nNow we know
# 10                                                                   Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new. And add a few more words like, love, happiness, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love,
# 11       Write a topic of song based on these words: like, make, time, come, tell, think, let, need, wanna, girl, way, money, black, new. (When he hears this, don't bother paying for it.) There are a variety of ways to process it, including\n\nUsing\n\nWhen you want to get to know something that you've never heard before\n\nUsing\n\nTo learn something new. The most obvious method, I think, is
# 12                                                                                                                                                                                                                       Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. This is a list of songs that are from the same genre
# 13                                                                                                                                                                                                                            Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. And all those things that are good for you.\n\n
# 14                                                         Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. It's a real job to make it.\n\nI do this because I want to make it. I want to make it because I want to make it. I want to make it because I want to make it.\n\nI want to make it because I want to make it.\n\nI
# 15  Write a topic of song based on these words: love, come, like, girl, baby, long, need, look, want, feel, new, make, time, way. Remember: these words are all about music, and if you don't know anything about music, you probably don't want to write a song. Be creative and find a song based on these words, and then decide where to draw the line between love, come, like, girl, baby, long, need

# %%
top_topics["final_topic"] = (
    top_topics["text"]
        .str.replace(r"^Write a topic.*?\.", "", regex=True)
        .str.strip()
)

# %%
top_topics["final_topic"]
# Out:
# 0                                                                                                                                                                                                                                            And so, I think the answer is, yes
# 1                                                                                                                                                                                                                                   This is a way of thinking I find inspiring.
# 2                                                               Let's say you're not gonna let me. I'll say, if you want me, you can take me.\n\nThen you can say something like, "I'm going to let you take me." And that's how it works.\n\nBut that's not how it works. It's
# 3                 and add your own. Like, let's say I wanna get married but I have a really nice first date and am still shy about it. I wish that I were born with a strong desire, but the fact that my mind, and body, is all too willing to see any kind of romantic or non
# 4                                                                                                                                                                                                                                                       I can't do that.\n\nI'm
# 5                                                                                                                                                                                                                               "You're so good here" is something you can hear
# 6                                               In the end, if you're feeling good, you'll love this.\n\nI've seen some of these, and I've seen others, but I'm not going to get into them.\n\nIf you're looking for a way to get more of these words in your lyrics, go for it
# 7         All your choices would be in 1 gram, so if you like them the way you feel most, try it! When a song comes out with no lyrics you're going to write for it, because there are many more words you could call out to every listener and say, "what a perfect piece!" or
# 8                                                                                                                                                                                                                                       If you think that's too easy, check out
# 9                                                                                                                                                                                                                                 All are beautiful songs, like.\n\nNow we know
# 10                                                                        And add a few more words like, love, happiness, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love,
# 11            (When he hears this, don't bother paying for it.) There are a variety of ways to process it, including\n\nUsing\n\nWhen you want to get to know something that you've never heard before\n\nUsing\n\nTo learn something new. The most obvious method, I think, is
# 12                                                                                                                                                                                                                         This is a list of songs that are from the same genre
# 13                                                                                                                                                                                                                                  And all those things that are good for you.
# 14                                                           It's a real job to make it.\n\nI do this because I want to make it. I want to make it because I want to make it. I want to make it because I want to make it.\n\nI want to make it because I want to make it.\n\nI
# 15    Remember: these words are all about music, and if you don't know anything about music, you probably don't want to write a song. Be creative and find a song based on these words, and then decide where to draw the line between love, come, like, girl, baby, long, need
# Name: final_topic, dtype: object

# %%
top_topics[['category', 'final_topic']]
# Out:
#    category  \
# 0    Topic1
# 1    Topic1
# 2    Topic1
# 3    Topic1
# 4    Topic2
# 5    Topic2
# 6    Topic2
# 7    Topic2
# 8    Topic3
# 9    Topic3
# 10   Topic3
# 11   Topic3
# 12   Topic4
# 13   Topic4
# 14   Topic4
# 15   Topic4
#
#                                                                                                                                                                                                                                                                   final_topic
# 0                                                                                                                                                                                                                                          And so, I think the answer is, yes
# 1                                                                                                                                                                                                                                 This is a way of thinking I find inspiring.
# 2                                                             Let's say you're not gonna let me. I'll say, if you want me, you can take me.\n\nThen you can say something like, "I'm going to let you take me." And that's how it works.\n\nBut that's not how it works. It's
# 3               and add your own. Like, let's say I wanna get married but I have a really nice first date and am still shy about it. I wish that I were born with a strong desire, but the fact that my mind, and body, is all too willing to see any kind of romantic or non
# 4                                                                                                                                                                                                                                                     I can't do that.\n\nI'm
# 5                                                                                                                                                                                                                             "You're so good here" is something you can hear
# 6                                             In the end, if you're feeling good, you'll love this.\n\nI've seen some of these, and I've seen others, but I'm not going to get into them.\n\nIf you're looking for a way to get more of these words in your lyrics, go for it
# 7       All your choices would be in 1 gram, so if you like them the way you feel most, try it! When a song comes out with no lyrics you're going to write for it, because there are many more words you could call out to every listener and say, "what a perfect piece!" or
# 8                                                                                                                                                                                                                                     If you think that's too easy, check out
# 9                                                                                                                                                                                                                               All are beautiful songs, like.\n\nNow we know
# 10                                                                      And add a few more words like, love, happiness, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love, love,
# 11          (When he hears this, don't bother paying for it.) There are a variety of ways to process it, including\n\nUsing\n\nWhen you want to get to know something that you've never heard before\n\nUsing\n\nTo learn something new. The most obvious method, I think, is
# 12                                                                                                                                                                                                                       This is a list of songs that are from the same genre
# 13                                                                                                                                                                                                                                And all those things that are good for you.
# 14                                                         It's a real job to make it.\n\nI do this because I want to make it. I want to make it because I want to make it. I want to make it because I want to make it.\n\nI want to make it because I want to make it.\n\nI
# 15  Remember: these words are all about music, and if you don't know anything about music, you probably don't want to write a song. Be creative and find a song based on these words, and then decide where to draw the line between love, come, like, girl, baby, long, need
